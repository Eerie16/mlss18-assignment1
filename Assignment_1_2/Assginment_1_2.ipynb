# %% [markdown]
# Welcome to your assignment on Pandas and Matplotlib!
# In case you face any difficulty or you have any doubts related to this assignment, or Pandas or Matplotlib in general, do not hesitate to ask on the Slack channel.

# %% [markdown]
# # Importing Libraries
#
# We shall start by importing the Python libraries you will need to run the code.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import matplotlib

# %matplotlib inline

# %% [markdown]
# # Importing the Data
#
# Import the data stored in "day.csv" using Pandas and store it in a DataFrame named df.
# Also, since the data contains many columns that you may find unnecessary, you may drop them off.

# %%
#Fill in the incomplete code here
df = pd.read_csv("day.csv")
drop_list = ['instant', 'season', 'yr','windspeed','atemp','weathersit','hum']
df=df.drop(columns=drop_list)
df
#Write code below to drop the columns given in drop_list. You can add or remove columns as per your convinience.
# Out:
#          dteday  mnth  holiday  weekday  workingday      temp  casual  \
# 0    2011-01-01     1        0        6           0  0.344167     331
# 1    2011-01-02     1        0        0           0  0.363478     131
# 2    2011-01-03     1        0        1           1  0.196364     120
# 3    2011-01-04     1        0        2           1  0.200000     108
# 4    2011-01-05     1        0        3           1  0.226957      82
# 5    2011-01-06     1        0        4           1  0.204348      88
# 6    2011-01-07     1        0        5           1  0.196522     148
# 7    2011-01-08     1        0        6           0  0.165000      68
# 8    2011-01-09     1        0        0           0  0.138333      54
# 9    2011-01-10     1        0        1           1  0.150833      41
# 10   2011-01-11     1        0        2           1  0.169091      43
# 11   2011-01-12     1        0        3           1  0.172727      25
# 12   2011-01-13     1        0        4           1  0.165000      38
# 13   2011-01-14     1        0        5           1  0.160870      54
# 14   2011-01-15     1        0        6           0  0.233333     222
# 15   2011-01-16     1        0        0           0  0.231667     251
# 16   2011-01-17     1        1        1           0  0.175833     117
# 17   2011-01-18     1        0        2           1  0.216667       9
# 18   2011-01-19     1        0        3           1  0.292174      78
# 19   2011-01-20     1        0        4           1  0.261667      83
# 20   2011-01-21     1        0        5           1  0.177500      75
# 21   2011-01-22     1        0        6           0  0.059130      93
# 22   2011-01-23     1        0        0           0  0.096522     150
# 23   2011-01-24     1        0        1           1  0.097391      86
# 24   2011-01-25     1        0        2           1  0.223478     186
# 25   2011-01-26     1        0        3           1  0.217500      34
# 26   2011-01-27     1        0        4           1  0.195000      15
# 27   2011-01-28     1        0        5           1  0.203478      38
# 28   2011-01-29     1        0        6           0  0.196522     123
# 29   2011-01-30     1        0        0           0  0.216522     140
# ..          ...   ...      ...      ...         ...       ...     ...
# 701  2012-12-02    12        0        0           0  0.347500     892
# 702  2012-12-03    12        0        1           1  0.452500     555
# 703  2012-12-04    12        0        2           1  0.475833     551
# 704  2012-12-05    12        0        3           1  0.438333     331
# 705  2012-12-06    12        0        4           1  0.255833     340
# 706  2012-12-07    12        0        5           1  0.320833     349
# 707  2012-12-08    12        0        6           0  0.381667    1153
# 708  2012-12-09    12        0        0           0  0.384167     441
# 709  2012-12-10    12        0        1           1  0.435833     329
# 710  2012-12-11    12        0        2           1  0.353333     282
# 711  2012-12-12    12        0        3           1  0.297500     310
# 712  2012-12-13    12        0        4           1  0.295833     425
# 713  2012-12-14    12        0        5           1  0.281667     429
# 714  2012-12-15    12        0        6           0  0.324167     767
# 715  2012-12-16    12        0        0           0  0.362500     538
# 716  2012-12-17    12        0        1           1  0.393333     212
# 717  2012-12-18    12        0        2           1  0.410833     433
# 718  2012-12-19    12        0        3           1  0.332500     333
# 719  2012-12-20    12        0        4           1  0.330000     314
# 720  2012-12-21    12        0        5           1  0.326667     221
# 721  2012-12-22    12        0        6           0  0.265833     205
# 722  2012-12-23    12        0        0           0  0.245833     408
# 723  2012-12-24    12        0        1           1  0.231304     174
# 724  2012-12-25    12        1        2           0  0.291304     440
# 725  2012-12-26    12        0        3           1  0.243333       9
# 726  2012-12-27    12        0        4           1  0.254167     247
# 727  2012-12-28    12        0        5           1  0.253333     644
# 728  2012-12-29    12        0        6           0  0.253333     159
# 729  2012-12-30    12        0        0           0  0.255833     364
# 730  2012-12-31    12        0        1           1  0.215833     439
#
#      registered   cnt
# 0           654   985
# 1           670   801
# 2          1229  1349
# 3          1454  1562
# 4          1518  1600
# 5          1518  1606
# 6          1362  1510
# 7           891   959
# 8           768   822
# 9          1280  1321
# 10         1220  1263
# 11         1137  1162
# 12         1368  1406
# 13         1367  1421
# 14         1026  1248
# 15          953  1204
# 16          883  1000
# 17          674   683
# 18         1572  1650
# 19         1844  1927
# 20         1468  1543
# 21          888   981
# 22          836   986
# 23         1330  1416
# 24         1799  1985
# 25          472   506
# 26          416   431
# 27         1129  1167
# 28          975  1098
# 29          956  1096
# ..          ...   ...
# 701        3757  4649
# 702        5679  6234
# 703        6055  6606
# 704        5398  5729
# 705        5035  5375
# 706        4659  5008
# 707        4429  5582
# 708        2787  3228
# 709        4841  5170
# 710        5219  5501
# 711        5009  5319
# 712        5107  5532
# 713        5182  5611
# 714        4280  5047
# 715        3248  3786
# 716        4373  4585
# 717        5124  5557
# 718        4934  5267
# 719        3814  4128
# 720        3402  3623
# 721        1544  1749
# 722        1379  1787
# 723         746   920
# 724         573  1013
# 725         432   441
# 726        1867  2114
# 727        2451  3095
# 728        1182  1341
# 729        1432  1796
# 730        2290  2729
#
# [731 rows x 9 columns]

# %% [markdown]
# # Plotting the data
#
# With the data stored in our Pandas dataframe, we are now ready to plot the data to gain some insights on the data.
# We will define functions for each plot to make our code re-usable.

# %% [markdown]
# But before plotting, you must set some parameters common to all the plots. This is done in order to make the visibility and readability of the plots better. This can be done by changing the default rc settings defined in the matplotlibrc configuration files. One example is given.

# %%
#Set plot size to 14" x 7" (Solved Exapmle)
matplotlib.rc('figure', figsize = (14, 7))

#Set the font size to 15
matplotlib.rc('font',size=15)

#Do not display the top and right frame lines
matplotlib.rcParams['axes.spines.top'] = False
matplotlib.rcParams['axes.spines.right'] = False

#You can try experimenting with the background color, grid lines and font style

# %% [markdown]
# ## Scatter Plot
#
# This is the most used plot for gaing insight into data while dealing with Machine Learning problems. For your convenience, the code for scatter plot is given as an exapmle.

# %%
def scatter_plot(x_data, y_data, x_label, y_label, title):
    fig, ax = plt.subplots()
    ax.scatter(x_data, y_data, s = 30, color = '#539caf', alpha = 0.75)
    
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    
scatter_plot(x_data = df['temp']
            , y_data = df['cnt']
            , x_label = 'Normalized temperature (C)'
            , y_label = 'Check outs'
            , title = 'Number of Check Outs vs Temperature')

# %% [markdown]
# # Histogram

# %%
#Fill the function given below
def histogram(data, x_label, y_label, title):
    fig, ax=plt.subplots()
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.hist(data,edgecolor='black',linewidth=1.3)


#Calling the function "histogram"
histogram(data = df['registered']
           , x_label = 'Check outs'
           , y_label = 'Frequency'
           , title = 'Distribution of Registered Check Outs')

# %% [markdown]
# # Line Plot

# %%
#Fill the function given below
def lineplot(x_data, y_data, x_label, y_label, title):
    fig, ax=plt.subplots()
    ax.set_title(title)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.plot(x_data,y_data,'b')
    
    
#Calling the function to create plot
lineplot(x_data = df['dteday']
         , y_data = df['cnt']
         , x_label = 'Date'
         , y_label = 'Total Checkouts'
         , title = 'Total Checkouts for Each Day')

# %% [markdown]
# # Comparing Two Line Plots
#
# This is useful for comparing two variables over a third variable. It must be noted that these variables may have different scales (they do in the example given below).

# %%
#Fill the function given below
def lineplot2y(x_data, x_label, y1_data, y1_label, y2_data, y2_label, title):
#     fig, ax1=plt.subplots()
#     ax1.set_title(title)
#     ax1.plot(x_data,y1_data,'r-')
#     ax1.set_xlabel(x_label)
#     ax1.set_ylabel(y1_label,color='r')
#     ax1.tick_params('y',colors='r')
#     ax2=ax1.twinx()
#     ax2.plot(x_data,y2_data,'b-')
#     ax2.set_ylabel(y2_label,color='b')
#     ax2.tick_params('y',colors='b')
#     plt.show()
    
    plt.subplot(2,1,1)
    plt.title(title)
    plt.plot(x_data,y1_data,'r-')
    plt.xlabel(x_label)
    plt.ylabel(y1_label)
    plt.subplot(2,1,2)
    plt.xlabel(x_label)
    plt.ylabel(y2_label)
    plt.plot(x_data,y2_data)
    plt.show()


#Calling the function to create plot
lineplot2y(x_data = df['dteday']
           , x_label = 'Date'
           , y1_data = df['casual']
           , y1_label = 'Casual Checkouts'
           , y2_data = df['registered']
           , y2_label = 'Registered Checkouts'
           , title = 'No. of Registered vs Casual Checkouts for Each Day')

# %% [markdown]
# # And You're Done!
#
# Congratulations on completing the second part of your first assignment. There are lots of plots you can explore and try on the numerous fields given in "day.csv". You can also do numpy operations on the data to derive more meaningful insights if you wish to.

# %% [markdown]
# You need to submit this Python notebook for this part of the assignment.
